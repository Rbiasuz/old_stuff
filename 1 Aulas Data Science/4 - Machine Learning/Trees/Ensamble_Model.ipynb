# %% [markdown]
# https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
#
# Documentação: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier

# %% [markdown]
# ## Importing Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\rodri\GitHub\My_Projects\1 Aulas Data Science\Data Sets/breast-cancer-wisconsin-data.zip')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Data Cleaning & EDA

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
d={'M':1,'B':0}
df['diagnosis'] = df['diagnosis'].map(d)
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

features = df.drop(['id', 'diagnosis', 'Unnamed: 32'], axis=1)
targets = df['diagnosis']

X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.20, stratify=targets,random_state=1)

# %% [markdown]
# ## Lista de modelos para treinar

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.metrics import accuracy_score

# Instantiate lr
lr = LogisticRegression(random_state=42, solver='newton-cg')

# Instantiate knn
knn = KNN(n_neighbors=15)

# Instantiate dt
dt = DecisionTreeClassifier(random_state=42)

# Define the list classifiers
classifiers = [('Logistic Regression', lr), ('K Nearest Neighbours', knn), ('Classification Tree', dt)]

# %%
# Iterate over the pre-defined list of classifiers
for clf_name, clf in classifiers:    
  
    # Fit clf to the training set
    clf.fit(X_train, y_train)    
  
    # Predict y_pred
    y_pred = clf.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
  
    # Evaluate clf's accuracy on the test set
    print('{:s} : {:.2f} %'.format(clf_name, accuracy*100))
# Out:
# Logistic Regression : 94.74 %
# K Nearest Neighbours : 95.61 %
# Classification Tree : 92.11 %

# %%
# Import VotingClassifier from sklearn.ensemble
from sklearn.ensemble import VotingClassifier

# Instantiate a VotingClassifier vc 
vc = VotingClassifier(estimators=classifiers)     

# Fit vc to the training set
vc.fit(X_train, y_train)   

# Evaluate the test set predictions
y_pred = vc.predict(X_test)

# Calculate accuracy score
accuracy = accuracy_score(y_test, y_pred)
print('Voting Classifier: {:.2f} %'.format(accuracy*100))
# Out:
# Voting Classifier: 97.37 %

# %% [markdown]
# ## Aplicação simples do modelo na prática:

# %%
novo_paciente = [[1.095e+01, 2.135e+01, 7.190e+01, 3.711e+02, 1.227e-01, 1.218e-01,
       1.044e-01, 5.669e-02, 1.895e-01, 6.870e-02, 2.366e-01, 1.428e+00,
       1.822e+00, 1.697e+01, 8.064e-03, 1.764e-02, 2.595e-02, 1.037e-02,
       1.357e-02, 3.040e-03, 1.284e+01, 3.534e+01, 8.722e+01, 5.140e+02,
       1.909e-01, 2.698e-01, 4.023e-01, 1.424e-01, 2.964e-01, 9.606e-02]]

# %%
vc.predict(novo_paciente)
# Out:
# array([0], dtype=int64)

# %%
novo_paciente = [[1.377e+01, 2.229e+01, 9.063e+01, 5.889e+02, 1.200e-01, 1.267e-01,
       1.385e-01, 6.526e-02, 1.834e-01, 6.877e-02, 6.191e-01, 2.112e+00,
       4.906e+00, 4.970e+01, 1.380e-02, 3.348e-02, 4.665e-02, 2.060e-02,
       2.689e-02, 4.306e-03, 1.639e+01, 3.401e+01, 1.116e+02, 8.069e+02,
       1.737e-01, 3.122e-01, 3.809e-01, 1.673e-01, 3.080e-01, 9.333e-02]]

# %%
vc.predict(novo_paciente)
# Out:
# array([1], dtype=int64)

# %%
lista_novos_pacientes
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 186       18.310         18.58          118.60     1041.0          0.08588
# 384       13.280         13.72           85.79      541.8          0.08363
# 429       12.720         17.67           80.98      501.3          0.07896
# 467        9.668         18.10           61.06      286.3          0.08311
# 540       11.540         14.44           74.65      402.9          0.09984
# 471       12.040         28.14           76.85      449.9          0.08752
# 35        16.740         21.59          110.10      869.5          0.09610
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 186           0.08468         0.08169             0.058140         0.1621
# 384           0.08575         0.05077             0.028640         0.1617
# 429           0.04522         0.01402             0.018350         0.1459
# ...

# %%
vc.predict(lista_novos_pacientes)
# Out:
# array([1, 0, 0, 0, 0, 0, 1], dtype=int64)

# %%
pacientes = pd.DataFrame(['Valentina', 'Rando', 'Ale', 'Ale2', 'Ale3', 'Rando2', 'Enzo'], columns=['Nome'])
pacientes
# Out:
#         Nome
# 0  Valentina
# 1      Rando
# 2        Ale
# 3       Ale2
# 4       Ale3
# 5     Rando2
# 6       Enzo

# %%
pacientes['Restultado estimado'] = vc.predict(lista_novos_pacientes)
pacientes
# Out:
#         Nome  Restultado estimado
# 0  Valentina                    1
# 1      Rando                    0
# 2        Ale                    0
# 3       Ale2                    0
# 4       Ale3                    0
# 5     Rando2                    0
# 6       Enzo                    1
