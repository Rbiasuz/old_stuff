# %% [markdown]
# ## Tips and Tricks
#
# #### Pandas tem diversas outras funcionalidades, e ainda podemos combinar mais de uma delas juntas pra obter diferentes resultados.,,
#
# Nessa parte, vamos passar por algumas que se mostram bem úteis ao longo dos trabalhos de análise e processamento de dados...

# %%
#Primeiro, carregamos as bibliotecas:
import numpy as np
import pandas as pd

# %%
#Vamos aproveitar o mesmo dataset que utilizamos antes, o famoso IRIS_DATA
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(np.concatenate((iris.data, np.array([iris.target]).T), axis=1), columns=iris.feature_names + ['target'])

df.tail(6)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 144     2.0
# 145     2.0
# 146     2.0
# 147     2.0
# 148     2.0
# 149     2.0

# %%
#Usualmente, nas primeiras etapas, queremos conhecer nossos dados, então é muito comum rodas as sequintes funções:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# target               150 non-null float64
# dtypes: float64(5)
# memory usage: 5.9 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
#Um jeito rápido de obter a dimensão é usar 'shape'
df.shape
# Out:
# (150, 5)

# %%
#Quando temos alguma categoria, geralmente queremos saber quantos valores únicos existem:
df['target'].nunique()
# Out:
# 3

# %%
#E, obviamente, queremos saber quais são esses valores únicos
df['target'].unique()
# Out:
# array([0., 1., 2.])

# %%
#Depois de saber quantos únicos temos e quais eles são, o passo natural é saber como estão distribuidos:
df['target'].value_counts()
# Out:
# 2.0    50
# 1.0    50
# 0.0    50
# Name: target, dtype: int64

# %%
#Essa aqui é minha favorita: Correlação de todos os valores por todos:
df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
#Outra tarefa comum é querer aplicar alguma transformação em alguma coluna...
#Podemos fazer isso definindo uma função qualquer:

def to_category(x):
    if x == 0:
        return 'Setosa'
    elif x == 1:
        return 'Virginica'
    else:
        return 'Versicolor'

# %%
#E após isso, usamos apply para a coluna que desejamos
df['target2'] = df['target'].apply(to_category)
print(df['target2'].value_counts())
df.head()
# Out:
# Setosa        50
# Virginica     50
# Versicolor    50
# Name: target2, dtype: int64
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target target2
# 0     0.0  Setosa
# 1     0.0  Setosa
# 2     0.0  Setosa
# 3     0.0  Setosa
# 4     0.0  Setosa

# %%
#Criando níveis por categoria, método 2
#Se você tive poucos valores (como é o nosso caso)

level_map = {0: 'espécie1', 1: 'espécie2', 2: 'espécie3'}
df['target3'] = df['target'].map(level_map)
print(df['target3'].value_counts())
df.head()
# Out:
# espécie3    50
# espécie2    50
# espécie1    50
# Name: target3, dtype: int64
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target target2   target3
# 0     0.0  Setosa  espécie1
# 1     0.0  Setosa  espécie1
# 2     0.0  Setosa  espécie1
# 3     0.0  Setosa  espécie1
# 4     0.0  Setosa  espécie1

# %%
#As vezes, queremos armazenar o nome das colunas em uma lista:
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target', 'target2', 'target3'],
#       dtype='object')

# %%
#E também os index
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
#Podemos ordenar por alguma coluna
df.sort_values(by='sepal width (cm)', inplace=True)
df.head(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 60                 5.0               2.0                3.5               1.0
# 62                 6.0               2.2                4.0               1.0
# 119                6.0               2.2                5.0               1.5
# 68                 6.2               2.2                4.5               1.5
# 41                 4.5               2.3                1.3               0.3
# 53                 5.5               2.3                4.0               1.3
# 93                 5.0               2.3                3.3               1.0
# 87                 6.3               2.3                4.4               1.3
# 81                 5.5               2.4                3.7               1.0
# 80                 5.5               2.4                3.8               1.1
#
#      target     target2   target3
# 60      1.0   Virginica  espécie2
# 62      1.0   Virginica  espécie2
# 119     2.0  Versicolor  espécie3
# 68      1.0   Virginica  espécie2
# 41      0.0      Setosa  espécie1
# 53      1.0   Virginica  espécie2
# 93      1.0   Virginica  espécie2
# 87      1.0   Virginica  espécie2
# 81      1.0   Virginica  espécie2
# 80      1.0   Virginica  espécie2

# %%
#Algo que é bem bacana também é, por exemplo, poder separar o nome do pessoal em diferentes colunas:

lista = ['Rodrigo Biasuz', 'Tony Stark', 'Steve Rogers', 'Bruce Banner', 'Natasha Hommanoff']

df1 = pd.DataFrame(lista, columns=['Nome'])
df1
# Out:
#                 Nome
# 0     Rodrigo Biasuz
# 1         Tony Stark
# 2       Steve Rogers
# 3       Bruce Banner
# 4  Natasha Hommanoff

# %%
#Podemos colocar numa lista
df1['Nome2'] = df1['Nome'].str.split(" ", expand=False)
df1
# Out:
#                 Nome                 Nome2
# 0     Rodrigo Biasuz     [Rodrigo, Biasuz]
# 1         Tony Stark         [Tony, Stark]
# 2       Steve Rogers       [Steve, Rogers]
# 3       Bruce Banner       [Bruce, Banner]
# 4  Natasha Hommanoff  [Natasha, Hommanoff]

# %%
#Ou em diferentes colunas
df1['Nome'].str.split(" ", expand=True)
# Out:
#          0          1
# 0  Rodrigo     Biasuz
# 1     Tony      Stark
# 2    Steve     Rogers
# 3    Bruce     Banner
# 4  Natasha  Hommanoff

# %%
#Se precisar deslocar seu DataFrame pra baixo ou pra cima, temos o método shift
df1.shift(1)
# Out:
#              Nome              Nome2
# 0             NaN                NaN
# 1  Rodrigo Biasuz  [Rodrigo, Biasuz]
# 2      Tony Stark      [Tony, Stark]
# 3    Steve Rogers    [Steve, Rogers]
# 4    Bruce Banner    [Bruce, Banner]

# %%
#para adicionar linhas na planilha, podemos colocar direto na última posição usando "shape"
df1.loc[df1.shape[0]] = ['col1', 'col2']
df1
# Out:
#                 Nome                 Nome2
# 0     Rodrigo Biasuz     [Rodrigo, Biasuz]
# 1         Tony Stark         [Tony, Stark]
# 2       Steve Rogers       [Steve, Rogers]
# 3       Bruce Banner       [Bruce, Banner]
# 4  Natasha Hommanoff  [Natasha, Hommanoff]
# 5               col1                  col2

# %%
#Outra função bem útil é a soma cumulativa!

#criando uma coluna numérica pra testarmos:

coluna = []
for i in range(df1.shape[0]):
    coluna.append(np.random.randint(10))
    
df1['numérica'] = coluna
df1
# Out:
#                 Nome                 Nome2  numérica
# 0     Rodrigo Biasuz     [Rodrigo, Biasuz]         9
# 1         Tony Stark         [Tony, Stark]         9
# 2       Steve Rogers       [Steve, Rogers]         3
# 3       Bruce Banner       [Bruce, Banner]         4
# 4  Natasha Hommanoff  [Natasha, Hommanoff]         0
# 5               col1                  col2         5

# %%
df1['soma_cumulativa'] = df1['numérica'].cumsum()
df1
# Out:
#                 Nome                 Nome2  numérica  soma_cumulativa
# 0     Rodrigo Biasuz     [Rodrigo, Biasuz]         9                9
# 1         Tony Stark         [Tony, Stark]         9               18
# 2       Steve Rogers       [Steve, Rogers]         3               21
# 3       Bruce Banner       [Bruce, Banner]         4               25
# 4  Natasha Hommanoff  [Natasha, Hommanoff]         0               25
# 5               col1                  col2         5               30

# %%
#Seguidamente nossos dados tem muitas colunas, mas precisamos apenas das numérias, ou as de texto...
df1.select_dtypes(include=['float64', 'int64'])
# Out:
#    numérica  soma_cumulativa
# 0         9                9
# 1         9               18
# 2         3               21
# 3         4               25
# 4         0               25
# 5         5               30

# %%
#Cópia!
#EXTREMAMENTE IMPORTANTE!

df2 = df1.copy()
df2.loc[0] = ['col1', 'col2', 2, 3]
df1
# Out:
#                 Nome                 Nome2  numérica  soma_cumulativa
# 0     Rodrigo Biasuz     [Rodrigo, Biasuz]         9                9
# 1         Tony Stark         [Tony, Stark]         9               18
# 2       Steve Rogers       [Steve, Rogers]         3               21
# 3       Bruce Banner       [Bruce, Banner]         4               25
# 4  Natasha Hommanoff  [Natasha, Hommanoff]         0               25
# 5               col1                  col2         5               30

# %%
#Iterar pelas colunas também é bem útil:
for index, row in df1.iterrows():
    print (row['Nome'], index)
# Out:
# Rodrigo Biasuz 0
# Tony Stark 1
# Steve Rogers 2
# Bruce Banner 3
# Natasha Hommanoff 4
# col1 5

# %%
#Trocar alguma letra de alguma coluna por outro valor:
df1['Nome'] = df1['Nome'].str.replace(' ','_')
df1
# Out:
#                 Nome                 Nome2  numérica  soma_cumulativa
# 0     Rodrigo_Biasuz     [Rodrigo, Biasuz]         9                9
# 1         Tony_Stark         [Tony, Stark]         9               18
# 2       Steve_Rogers       [Steve, Rogers]         3               21
# 3       Bruce_Banner       [Bruce, Banner]         4               25
# 4  Natasha_Hommanoff  [Natasha, Hommanoff]         0               25
# 5               col1                  col2         5               30

# %%
#Juntar duas colunas´:
df1['juntando'] = df1["numérica"].astype(str) + ' - ' + df1["Nome"]
df1
# Out:
#                 Nome                 Nome2  numérica  soma_cumulativa  \
# 0     Rodrigo_Biasuz     [Rodrigo, Biasuz]         9                9
# 1         Tony_Stark         [Tony, Stark]         9               18
# 2       Steve_Rogers       [Steve, Rogers]         3               21
# 3       Bruce_Banner       [Bruce, Banner]         4               25
# 4  Natasha_Hommanoff  [Natasha, Hommanoff]         0               25
# 5               col1                  col2         5               30
#
#                 juntando
# 0     9 - Rodrigo_Biasuz
# 1         9 - Tony_Stark
# 2       3 - Steve_Rogers
# 3       4 - Bruce_Banner
# 4  0 - Natasha_Hommanoff
# 5               5 - col1

# %%
#Adicionando 
df['col_total']     = df.apply(lambda x: x.sum(), axis=1)
df.loc['row_total'] = df.apply(lambda x: x.sum())

# %%
#Options
pd.options.display.max_columns = 50  # None -> No Restrictions
pd.options.display.max_rows = 200    # None -> Be careful with this 
pd.options.display.max_colwidth = 100
pd.options.display.precision = 3

# %%
# estilo - colocando uma cor por determinada condição
def color_negative_red(val):
    color = 'red' if val < 3 else 'black'
    return 'color: %s' % color
s = df.style.applymap(color_negative_red)
s
# Out:
# <style  type="text/css" >
#     #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row0_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row0_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row0_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row0_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row0_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row1_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row1_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row1_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row1_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row1_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row2_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row2_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row2_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row2_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row2_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row3_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row3_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row3_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row3_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row3_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row4_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row4_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row4_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row4_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row4_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row5_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row5_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row5_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row5_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row5_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row6_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row6_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row6_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row6_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row6_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row7_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row7_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row7_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row7_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row7_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row8_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row8_col1 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row8_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row8_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row8_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row9_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row9_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row9_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row9_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row9_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row10_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row10_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row10_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row10_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row10_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row11_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row11_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row11_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row11_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row11_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row12_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row12_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row12_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row12_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row12_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row13_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row13_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row13_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row13_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row13_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row14_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row14_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row14_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row14_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row14_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row15_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row15_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row15_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row15_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row15_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row16_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row16_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row16_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row16_col3 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row16_col4 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row17_col0 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row17_col1 {
#             color:  black;
#         }    #T_ee975ab0_c37e_11e9_97b6_7440bbab6b94row17_col2 {
#             color:  red;
#         }    #T_ee975ab0_c37e_11e9_97b6_744

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

s = df.style.set_table_styles(
[{'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}]
)
s
# Out:
# <style  type="text/css" >
#     #T_f06877d0_c37e_11e9_8a0c_7440bbab6b94 tr:hover {
#           background-color: yellow;
#     }</style><table id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length (cm)</th>        <th class="col_heading level0 col1" >sepal width (cm)</th>        <th class="col_heading level0 col2" >petal length (cm)</th>        <th class="col_heading level0 col3" >petal width (cm)</th>        <th class="col_heading level0 col4" >target</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row0_col0" class="data row0 col0" >5.1</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row0_col1" class="data row0 col1" >3.5</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row0_col2" class="data row0 col2" >1.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row0_col3" class="data row0 col3" >0.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row1_col0" class="data row1 col0" >4.9</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row1_col2" class="data row1 col2" >1.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row1_col3" class="data row1 col3" >0.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row1_col4" class="data row1 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row2_col0" class="data row2 col0" >4.7</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row2_col1" class="data row2 col1" >3.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row2_col2" class="data row2 col2" >1.3</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row2_col3" class="data row2 col3" >0.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row2_col4" class="data row2 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row3_col0" class="data row3 col0" >4.6</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row3_col1" class="data row3 col1" >3.1</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row3_col2" class="data row3 col2" >1.5</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row3_col3" class="data row3 col3" >0.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row3_col4" class="data row3 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row4_col1" class="data row4 col1" >3.6</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row4_col2" class="data row4 col2" >1.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row4_col3" class="data row4 col3" >0.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row4_col4" class="data row4 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row5_col0" class="data row5 col0" >5.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row5_col1" class="data row5 col1" >3.9</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row5_col2" class="data row5 col2" >1.7</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row5_col3" class="data row5 col3" >0.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row5_col4" class="data row5 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row6_col0" class="data row6 col0" >4.6</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row6_col1" class="data row6 col1" >3.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row6_col2" class="data row6 col2" >1.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row6_col3" class="data row6 col3" >0.3</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row6_col4" class="data row6 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row7_col0" class="data row7 col0" >5</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row7_col1" class="data row7 col1" >3.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row7_col2" class="data row7 col2" >1.5</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row7_col3" class="data row7 col3" >0.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row7_col4" class="data row7 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row8_col0" class="data row8 col0" >4.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row8_col1" class="data row8 col1" >2.9</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row8_col2" class="data row8 col2" >1.4</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row8_col3" class="data row8 col3" >0.2</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row8_col4" class="data row8 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row9_col0" class="data row9 col0" >4.9</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row9_col1" class="data row9 col1" >3.1</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row9_col2" class="data row9 col2" >1.5</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row9_col3" class="data row9 col3" >0.1</td>
#                         <td id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94row9_col4" class="data row9 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f06877d0_c37e_11e9_8a0c_7440bbab6b94level0_row10" class="row_heading level0 row10" >10</th>
