# %% [markdown]
# # Loading and Saving Data!
#
# ## pd_read...
#
#     Métodos para ler os dados (entrada)
#
# ## df_to_...
#
#     Método para salvar os dados (saída)

# %%
#Primeiro, como sempre, carregamos as bibliotecas

import numpy as np
import pandas as pd

# %% [markdown]
# ### Carregando os dados:

# %% [markdown]
# #### O mais comum de todos: Lendo um CSV (Arquivo separado por vírgulas)

# %%
df = pd.read_csv('Poke.csv')
df.head(15)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %% [markdown]
# ### Outro tipo de arquivo comum: Excel

# %%
pd.read_excel('Planilha.xlsx',sheet_name='Sheet1')
# Out:
#    Coluna A  Coluna B  Coluna C  Coluna D
# 0        10        15        10        20
# 1        11        20        50        20
# 2        23        51        51        12
# 3        23        21        20        20
# 4        56        32        15        21

# %%
pd.read_excel('Planilha.xlsx',sheet_name='Sheet2')
# Out:
#     20  50  20.1   10
# 0  232  55   203   20
# 1  221  23    50   21
# 2    5  11    52   21
# 3   60  52    50  888
# 4   20  10    30   40

# %%
pd.read_excel('Planilha.xlsx',sheet_name='Sheet2', header=None)
# Out:
#      0   1    2    3
# 0   20  50   20   10
# 1  232  55  203   20
# 2  221  23   50   21
# 3    5  11   52   21
# 4   60  52   50  888
# 5   20  10   30   40

# %% [markdown]
# ### Ler HTML é muito útil para retirar alguma informação direto de algum site:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0].head(15)
# Out:
#                                             Bank Name                City  ST  \
# 0                 Washington Federal Bank for Savings             Chicago  IL
# 1     The Farmers and Merchants State Bank of Argonia             Argonia  KS
# 2                                 Fayette County Bank          Saint Elmo  IL
# 3   Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 4                                      First NBC Bank         New Orleans  LA
# 5                                       Proficio Bank  Cottonwood Heights  UT
# 6                       Seaway Bank and Trust Company             Chicago  IL
# 7                              Harvest Community Bank          Pennsville  NJ
# 8                                         Allied Bank            Mulberry  AR
# 9                        The Woodbury Banking Company            Woodbury  GA
# 10                             First CornerStone Bank     King of Prussia  PA
# ...

# %%
df = pd.read_html('http://www.cultura.ufpa.br/dicas/htm/htm-cor2.htm', header=0)[0]
df

# %% [markdown]
# ### Ler o clipboard, ou seja, ler o que está no seu CTRL+C, também é útil para agilizar alguma atividade!

# %%
pd.read_clipboard()
# Out:
#    6 Seaway Bank and Trust Company     Chicago  IL  19328  \
# 0  7        Harvest Community Bank  Pennsville  NJ  34951
# 1  8                   Allied Bank    Mulberry  AR     91
#
#                    State Bank of Texas    January 27, 2017 January 29, 2019
# 0  First-Citizens Bank & Trust Company    January 13, 2017     May 18, 2017
# 1                         Today's Bank  September 23, 2016     May 13, 2019

# %%
#Existem outros métodos de leitura de outros bancos de dados específicos, como SQL, por exemplo, mas esses não são tão comuns.

# %% [markdown]
# ### Salvando os dados:

# %%
#Primeiro, vamos criar um novo dataframe:

dicionário = {
    "Col_A":(1,2,3),
    "Col_B":(3,2,1),
    "Col_C":(6,6,6)
}

df = pd.DataFrame(dicionário)
df
# Out:
#    Col_A  Col_B  Col_C
# 0      1      3      6
# 1      2      2      6
# 2      3      1      6

# %% [markdown]
# #### Para salvar, acessamos o método to_(nome da extesão) do DataFrame,
# #### alguns exemplos comuns:
#
# * df.to_csv
# * df.to_html
# * df.to_excel
# * df.to_clipboard
# * df.to_json

# %%
df.to_csv('nome_do_arquivo.csv')

# %%
df.to_clipboard()
